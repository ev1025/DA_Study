# %% [markdown]
# <a href="https://colab.research.google.com/github/ev1025/DA/blob/main/DA_Reference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 사전지식(References)

# %% [markdown]
# ### 데이터 분석 방법론 : CRISP-DM (CRoss Industry Standard Process for Data Mining)

# %% [markdown]
# **1) Business Understanding**
# - 비즈니스 배경 및 목적 (비즈니스가 처한 상황, 문제점, 사업목표, 조직구성 등)
# `ex) 대리점 매출저하로 인한 사업성장문제를 개선하기 위한 방법`
# - 분석 목적 및 목표 설정 (데이터분석 이유, 목적, 효과)
# `ex) 비즈니스 목적이 매출을 증대시키는 것 이라면 분석 목적은 증대 방법을 탐색하는 모델 수립`

# %% [markdown]
# **2) Data Understanding**
# - 초기데이터 수집 : 고객데이터, 상품데이터, 구매데이터, 로그데이터 등
# - 데이터 기술(describe) : 확보데이터에 대한 설명 자료
# `ex) 테이블 별 데이터 수, 테이블 항목 데이터유형(categoric, iterator, integer, numeric, character)`

# %% [markdown]
# **3) Data Preprocessing**
# - 데이터누락, 오류, 의미해석불가 데이터들 =>정제
# - 정제된 데이터로 새로운 데이터를 생성하거나 통합
# - 데이터에 대한 이해를 통해 데이터 종류, 건수, 분석기간, 분석기준을 확정
# > **Tip** : 활용가능한 모든 데이터를 분석하기보다 목적에 맞게 최적화하여 분석(F검정 후 t검정을 통과하는 정도면 충분)

# %% [markdown]
# **4) Modeling**
# - 모델 선정 가이드
#    - 데이터량이 충분한가?(신뢰도)
#    - 데이터의 품질이 중요한 모델인가?
#    - 데이터의 형태가 모델에 적합한가? (변환을 하면 되지만, 성능에 영향을 줄 수 있다)
# - 테스트 방안 설계,수립
#    - 모델링 평가지표와 basline을 정해두어야한다.
# ex) 지도학습의 오류율 / 비지도학습의 오차값평균, 중심점, 실루엣

# %% [markdown]
# **5) Evaluation**
# - 모델의 성능이 목표와 일치 하는지, 비즈니스에 어떤 의미와 효과가 있을지 정리
# - 평가지표 분석 및 모델성능 최적화(반복)

# %% [markdown]
# **6) Deployment(배포)**
# - 결과 발표 및 보고 단계
# - 데이터와 비즈니스에 대한 이해, 전처리단계, 모델링기술, 결과와 시사점을 정리
# - 향후 자동화 구축방안과 모니터링 방안을 추가

# %% [markdown]
# #### KDD(Knowledge Discovery in Database) - 고전 분석방법론

# %% [markdown]
# - 기술과 데이터베이스를 중심으로 insight 발굴을 위한 절차와 단계
# - BI(Business Intelligence)라고도 불리며 DBMS를 운영하는 조직에서 사용가능하다.

# %% [markdown]
# **1) Selection(데이터 선택)**
#  - Raw data에서 분석에 필요한 자료를 선택, 도메인 이해와 과제목표설정)
#
# **2) Prerprocessing(데이터 전처리)**
# - 데이터 셋의 노이즈, 이상치, 결측치를 정제
#
# **3) Transformation(데이터 변환)**
# - 분석 목적에 따라 Feature를 생성, 선택하고 데이터마이닝 할 수 있도록 데이터를 분리
#
# **4) Data Mining**
# - 분석목적에 맞는 데이터마이닝 알고리즘을 선택하여 데이터마이닝 실행
#
# **5) Interpretation/Evaluation(해석/평가)**
# - 데이터마이닝 결과를 해석,평가하고 결과가 충족하지 않았을 땐 데이터 선택과 데이터마이닝 반복수행
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 문제를 쪼개어 분석 : MECE(Mutually Exclusive Collectively Exhaustive)

# %% [markdown]
# **문제해결을 위한 이슈 분석**
#
# **1. 핵심질문을 정의한다**
#    - 과거,현재,미래 상황(배경)과 현재 직면한 문제 및 장애요소 정의
#
# **2. 핵심질문을 이슈로 바꾼다.**
#    - 핵심질문을 이슈로 발전시켜서 실천적이고 의사결정에 도움이 되도록 구체화
#
# **3. 이슈를 잘게 쪼갠다.(MECE)**
#    - 이슈를 상위이슈와 하위이슈(인과관계나 해결책)의 관계로 구성된다.
#    - 하위 이슈 상호간에는 중복과 누락이 없어야한다.
#    `ex) 사람을 남자, 여자로 나누면 중복이없고, 누락되는 사람이 없다`
#    - 하위 이슈의 단계는 충분히 검증 가능한 데이터 수집이나 분석을 할 수 있는 수준까지 나눈다.
#
# **4. 쪼갠 이슈를 해결할 가설을 세우고 근거를 파악한다.**
# - 도출된 이슈에 대한 가설을 미리 상정하고 이를 입증하기 위한 분석을 진행해야한다.
# **5. 작업계획을 수립한다.**

# %% [markdown]
# ## 가설수립 - 연역적 추론과 귀납적 추론

# %% [markdown]
# ### 연역적 추론(Inductive Reasoning)

# %% [markdown]
# - 미리 정해놓은 예상 결과를 검증하는 방법
# - 데이터와 산출된 정보는 이론을 증명하고 검증하는 **수동적 역할**
# - 가설의 **예외적인 결과에 대해서 설명하기 어렵다**는 단점이 있다.
#    `ex) 가설 : 매일 댓글을 다는 사용자는 액티브유저이다`
#      `-> 매일 접속은 하지만 댓글만 안다는 유저는 설명불가`
#
# - **연구단계** : 배경지식 -> 가설 -> 연구설계 -> 측정 -> 자료수집 -> 분석 -> 경험적 일반화
#    - 직접추론 : P이면 Q이다 -> Q이면 P이다(대우명제)
#    - 간접추론 : 모든 사람은 죽는다 -> 나는 사람이다 - > 나는 죽는다.

# %% [markdown]
# ### 귀납적추론(Deductive Reasoning)

# %% [markdown]
# - 어떤 현상을 관찰하여 특성을 모두 열거하고 측정하여 유의미한 결과를 일반화 하는 방법(패턴찾기)
# - 데이터는 이론을 새롭게 발견하고 명료화 하는 **능동적 역할**
# - 데이터 분석가의 직관이 개입될 여지가 적다.
# - **인과관계의 오류가 발생할 수 있고 일반화가 어렵다.**
# `ex) 맹자도 죽었다, 공자도 죽었다. 그러므로 사람은 죽는다`
# `ex) 비둘기는 난다, 참새도 난다, 그러므로 모든 새는 난다 => 일반화 모순`
# - **연구단계** : 경험적 관찰 -> 가설 -> 연구설계 -> 측정 -> 자료수집 -> 분석 -> 이론수립

# %% [markdown]
# > **연역적 추론이 귀납적 추론보다 효율성이 높다.**
# - 경험주의적 사고를 바탕으로하기 때문에 가설 생성에 소요되는 시간이 적다.
# - 하지만 최근에는 기술의 발달로 데이터 수집과 처리가 빨라지면서 많은 데이터를 필요로하는 귀납적추론의 단점이 해소되는 상황

# %% [markdown]
# ### 데이터분석에서 연역 + 귀납 상호보완적으로 사용

# %% [markdown]
# - 도메인지식과 분석가의 직관을 이용한 연역적 추론
# - 데이터 탐색을 통한 패턴/특성을 도출하는 귀납적 추론
# - 두 분석방법을 통해 MECE(=분할정복)

# %% [markdown]
# ## 전환률(Conversion Rate, CVR)

# %% [markdown]
# - 전환수 / 클릭수 *100 = 전환률
# - 클릭은 유효클릭과 무효클릭으로 나뉘며 전환률을 구할 때 따로 구분하진 않음
# - 정밀하게 하기 위해선 유효클릭만 사용해도 좋음

# %% [markdown]
# ## 퍼널분석(Funnel Analysis)

# %% [markdown]
# - 설계자가 설계한 **유저경험루트를 고객이 잘 따라오는지** 최초유입부터 단계까지 나누어 분석하는 기법
# - 분석을 각 단계별 **이탈고객 수**를 확인 할 수 있다.
# - 각 단계를 통과할 때 마다 유저수가 줄어들게 되어 깔데기(Funnel)분석이라한다.
# - 각 단계를 넘어가는 것을 **전환(Conversion)**이라고 부르고 그 비율을 **전환율(Conversion Rate)**
#
# https://datarian.io/blog/funnel-analysis

# %% [markdown]
# #### 분석목적 : 최종단계에 도착하는 유저 수를 늘리는 것

# %% [markdown]
# 1. 페이지뷰를 늘린다.
#    - 유료광고 예산을 늘리거나 자극적 문구나 이미지를 사용
# 2. 각 단계별 전환율을 높인다.
#    - 단계마다 문제점 파악(단계의 설명이 부족하진 않은지? 고객 관점에서 파악)
# 3. 퍼널의 단계를 줄인다.
#    - 요즘 카카오 구글 계정연동 하는 이유 -> 쉽게 가입이 되어서 이탈률 감소

# %% [markdown]
# ## 코호트 분석(Cohort Analysis)

# %% [markdown]
# - 시간의 흐름에 따라 고객을 세분화하는 분석기법
# - 참고자료: https://datarian.io/blog/cohort-analysis
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 클래식 리텐션(Classic Retention) - Feat. AARRR

# %% [markdown]
# **AARRR**
# - 그로스해킹의 대표적인 분석 프레임워크인
# - Acquisition(사용자획득) -> Activation(사용자활성화)->Retention(사용자유지)->Revenue(매출)->Referral(전파)

# %% [markdown]
# **Classic Retention**
# - 지정한 날의 특정 유저군의 몇 %가 유지되었는지(방문이나 특정기능사용여부 등)를 보고 측정하는 것
# - 밑의 그림에서 12-02의 리텐션은 40%
# - **클래식 리텐션의 한계** : 사용자 B는 Day2에는 이용하지 않았지만 Day3에도 이용을 하여 Retention에 포함되어야 하지만, 실제로 포함되지 않음. 따라서 상황에 따라 다양한 리텐션 방법을 사용해야한다.
# `참고자료` : https://datarian.io/blog/classic-retention
# `리텐션 방법` : https://blog.ab180.co/posts/retention-series-3-1
#
# ![d.png](data:image/png;base64,...)

# %% [markdown]
# ### AARRR

# %% [markdown]
# ### 로그설계

# %% [markdown]
# ### Aqile, Waterfall

# %% [markdown]
# ### 고객의 접근 수를 늘리는 법

# %% [markdown]
# -  이용후기에 관련텍스트를 많이 넣어서 키워드검색이 되도록 유도한다.

# %% [markdown]
# # 데이터 이론

# %% [markdown]
# ### 데이터 경량화

# %% [markdown]
# #### 1) 데이터를 쪼개어 살펴보기
#
# - 데이터가 너무 클 경우엔 데이터를 찾고자 하는 부분에 맞추어 국소적으로 관찰해 볼 수 있습니다.
# - 특정 문제에 대한 가설을 바탕으로 작은 단위의 문제로 만들어 진행한 뒤, 각각의 결과를 바탕으로 인사이트를 얻을 수 있습니다.
#
# #### 2) 데이터의 경량화
#
# **데이터 샘플링** :
#
# - 데이터가 너무 큰 경우, 다양한 방식으로 샘플링 해서 진행할 수 있습니다.
#
# **메모리 최적화:**
#
# 데이터 파일을 효율적으로 활용할 수 있도록 메모리를 줄여봅니다.
#
# - 데이터 코드화: object -> int 등
# - 데이터 형식 변환: 가능한 적은 byte로 줄이기 / object -> category, int64 -> int32
# - 파일 포맷 변환: parquet ,hdf5 등
#
# **그 외 방법:**
#
# - 데이터의 경량화는 아니지만, 파이썬 자체의 내장함수를 잘 조합해서 활용하면 훨씬 빠르게 활용할 수 있는 함수들이 있습니다.
#
# #### 3) 빅데이터 처리 플랫폼 활용
#
# 다양한 빅데이터 처리 플랫폼들이 서비스를 제공하고 있습니다.
# 이러한 플랫폼의 서비스를 활용해서 좀 더 빠르고 간편하게 데이터 분석을 진행해볼 수도 있습니다.
#
# 다만, 해당 플랫폼의 서비스를 활용하기 위해선 튜토리얼 등을 어느정도 익힐 필요가 있습니다.
#
# - 빅쿼리 관련 개념 레퍼런스
#     1. [토크아이티 세미남 (유튜브 - 빅쿼리에 대한 소개)](https://www.youtube.com/watch?v=57Zb2_GIMlA)
#     2. [빅쿼리란? (유튜브 - 빅쿼리에 대한 소개)](https://www.youtube.com/watch?v=LhksTFvVriU)
# - spark 관련 개념 레퍼런스
#     1. [민짱님의 아파치 스파크 개념 설명 1](https://www.youtube.com/watch?v=D3TLh_QVGPg)
#     2. [민짱님의 아파치 스파크 개념 설명2](https://www.youtube.com/watch?v=XCZk8J23mXM)
#     3. [**스파크의 연산원리 - 딥상어동님의 티스토리 블로그**](https://gibles-deepmind.tistory.com/136)

# %% [markdown]
# # 필요 기술

# %% [markdown]
# ### 빅데이터 4V

# %% [markdown]
# https://m.boostcourse.org/ds103/lecture/352625

# %% [markdown]
# **1. Volume (규모의 가치)**
#    - 데이터의 전체 규모를 말한다.
#    - 데이터의 규모가 크다고 항상 큰 가치를 가지진 않는다.
#    - 고객과의 관계를 얻고, 유지, 성장, 관리를 통해 더 많은 데이터를 확보할 수 있고, 통찰력을 가질 수 있다.

# %% [markdown]
# **2. Velocity(속도의 가치)**
# - 정보를 빠르게 처리할수록 쿼리, 보고서, 대시보드를 통해 유연한 결과를 얻을 수 있다.
# - 빠른 데이터 통합과 분석능력은 적시에 정확한 결정으로 고객관계관리 목표를 달성할 수 있게 한다.

# %% [markdown]
# **3. Variety(다양성의 가치)**
# - CRM, SNS, 콜센터 로그 등을 통한 다양한 고객데이터가 있을수록 더 다양한 시각을 키울 수 있다.
# - 이를 통해 고객여정지도와 개인화로 더 밀접한 관리가 가능하다.

# %% [markdown]
# **4. Veracity(정확성의 가치)**
# - 고객데이터는 정확한 결정을 내리기 위해 통합,정제되고 일관성,최신성을 가져야한다.

# %% [markdown]
# ### 1. MySQL

# %% [markdown]
# ### 2. 하둡

# %% [markdown]
# - 디스크형식의 데이터 분석도구
# - 컴퓨터 클러스터에 퍼져있는 거대 데이터 셋을 분산 환경에서 쉬운 프로그래밍 모델로 처리하는 프레임워크
# - 라이브러리가 어플리케이션 단에서 일어나느 결함을 찾아내고 처리하여 고가용성 서비스를 할 수 있다.
#
# **모듈**
# - **Hadoop Common**: 다른 하둡 모듈을 지원하기 위한 공통적인 유틸리티
# - **Hadoop Distributed File System (HDFS™)**: 어플리케이션이 사용하는 데이터에 높은 처리량으로 접근할 수 있도록 돕는 분산 파일 시스템
# - **Hadoop YARN** : 작업 스케쥴링과 클러스터 자원 관리를 위한 프레임워크
# - **Hadoop MapReduce**: 거대 데이터셋을 병렬 처리하기 위한 YARN 기반 시스템
# - **Hadoop Ozone**: 하둡을 위한 객체 저장소
# - **Hadoop Submarine**: 하둡을 위한 기계 학습 엔진

# %% [markdown]
# **HDFS - 하둡 분산 파일 시스템**
# - 사용자가 하둡 클러스터에 있는 데이터에 접근할 수 있도록 하는 데이터 저장소 모듈
# - 거대한 데이터를 데이터블록으로 나누고, 다양한 인터페이스로 관리
# - 각 데이터 블록은 여러개의 하드웨어로 복사되어 한 장치에서 결함이 발생하더라도 데이터를 이용할 수 있다.

# %% [markdown]
# **Hadoop MapReduce**
# - 하둡어플리케이션이 실행하는 두 개의 다른 작업
# - 매퍼는 각 요소를 Key와 Value(튜플)의 형태로 나누어 데이터셋을 변환한다.
# - 리듀서는 맵의 결과를 입력받아서 더 작은 튜플집합으로 합친다.
# - 클러스터의 모든 노드에 병렬화되어 페타바이트 단위의 데이터도 몇시간 안에 정렬가능
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Hadoop YARN**
# - HDFS에 저장되어 있는 데이터를 실행하고 처리하기 위한 다른 데이터처리 엔진을 제공
# - 스케줄링 작업 제공

# %% [markdown]
# ### 3. Pyspark

# %% [markdown]
# - In-memory형식의 데이터 분석도구 -> 디스크형식인 하둡보다 훨씬 빠름
# - 클러스터 구조의 분산 병렬처리(클러스터구조란 여러컴퓨터를 하나의 컴퓨터처럼 사용 마스터-슬레이브들)
# - 메인 언어는 Scala (제일 빠르게 사용할 수 있음)
# - 스파크 설명 : https://gibles-deepmind.tistory.com/136
#
# **두가지 연산 프로세서**
# 1. Driver : 일감을 나눠주는 여왕벌(구체적 명령 지시)
#    - sparkContext : Driver의 일종으로 디스크가 아닌 RDD(탄력분산데이터셋)을 생성
#    - sparkSession : RDD와 데이터프레임, 데이터셋 등을 생성할 수 있음
# 2. Executor,worker node : 꿀벌(명령 수행 후 보고)
#
# **RDD**
# - Immutable(변함없는)구조 => 새로운 RDD를 만들어도 기존의 RDD는 변하지 않음
# - fault-tolerance(에러에 관대) 하나의 executor에서 에러 발생 시 cluster manager가 다른 executor에 작업을 부여
#
# **Transfomation**
# - 스파크의 연산자, 이론적으로 무한히 중첩가능
#
# **Lazy Execution(지연연산)과 Action**
# - Transformation에 아무리 많은 연산을 중첩해 두어도 Action명령을 하지 않으면 실행되지 않는다.

# %% [markdown]
# ### 4. 빅쿼리(구글)

# %% [markdown]
# - 구글클라우드 기반 데이터 웨어하우스
# - SQL기반으로 작동하며 확장가능한 대규모컴퓨팅자원(콜로서스{스토리지}, Dremel{클러스터},주피터{분산형 메모리 셔플계층})이 있다.
# - 운영 및 관리가 필요없다
# - 사용한 만큼만 과금
# - 머신러닝을 SQL기반으로 만든다.(회귀,분류,추천, 인공신경망일부)

# %% [markdown]
# ### 5. AWS

# %% [markdown]
# ### 6. 태블로

# %% [markdown]
# ### 7. GA, 구글서치콘솔, Listening Mind(유료)

# %% [markdown]
# # 추천책

# %% [markdown]
# **[딥러닝]**
# - 비전 시스템을 위한 딥러닝
# https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000002942588
#
# - 파이썬으로 만드는 OpenCV 프로젝트
#  https://product.kyobobook.co.kr/detail/S000001033077
#
# - Deep Learning Cookbook
# https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000003455398
#
# - 케라스 창시자에게 배우는 딥러닝
# https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000002912109
#
# - 케라스로 구현하는 고급 딥러닝 알고리즘
# https://product.kyobobook.co.kr/detail/S000001766396
#
# - GAN 첫걸음
# https://product.kyobobook.co.kr/detail/S000001810359
#
# - 데이터 중심 애플리케이션 설계
# https://product.kyobobook.co.kr/detail/S000001766328
#
# - Apache Airflow 기반의 데이터 파이프라인
# https://product.kyobobook.co.kr/detail/S000001952239
#
# **[머신러닝]**
# - 파이썬 라이브러리를 활용한 머신러닝
# https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000002942609
#
# - 파이썬을 활용한 머신러닝 쿡북
# https://ebook-product.kyobobook.co.kr/dig/epd/ebook/E000002942385
#
# **[파이프라인]**
# - 데이터 중심 애플리케이션 설계
# https://product.kyobobook.co.kr/detail/S000001766328
#
# - Apache Airflow 기반의 데이터 파이프라인
# https://product.kyobobook.co.kr/detail/S000001952239
#
# **[알고리즘]**
# - 잠자는 코딩 브레인을 깨우는 알고리즘 퍼즐 69
# http://www.yes24.com/Product/Goods/69063562
#
# - 파이썬 알고리즘 인터뷰
# https://github.com/onlybooks/algorithm-interview
#
# - 이것이 취업을 위한 코딩 테스트다 with 파이썬
# http://www.yes24.com/Product/Goods/91433923
#
# **[데이터 분석가]**
# 1. 그로스 해킹 (양승화 저)
# 2. 린 분석 (엘리스테어 크롤, 벤저민 요스코비츠 저)
# 3. 빅데이터를 활용한 예측마케팅 전략 (외머 아튼, 도미니크 레빈 저)
# 4. 틀리지 않는 법 (조던 엘렌버그 저)
# 5. 디맨드 (에이드언 슬라이워츠키 저)
#
# **[데이터 엔지니어]**
# - Do it 점프 투 장고
# https://product.kyobobook.co.kr/detail/S000001817996
# - Do it 장고를 이용한 ~~~~ (도커그림있는거)
# https://product.kyobobook.co.kr/detail/S000001817993
#
# **[기타]**
# - 소프트 스킬
# http://www.yes24.com/Product/Goods/111096733
# - 커리어 스킬
# http://www.yes24.com/Product/Goods/71829578
#
# - 완벽한 공부법
# https://product.kyobobook.co.kr/detail/S000001792100
#
# - 빅데이터 커리어 가이드북
# https://product.kyobobook.co.kr/detail/S000001834719
#
# - 그림으로 이해하는 aws 구조와 기술

# %% [markdown]
# ### 섹션5 조대희 코치님 추천 영상
# 1) 빅데이터센터 연구원이 말하는 데이터의 중요성
# - https://www.youtube.com/watch?v=LVEZNLxuD-4&t=1s
#
# 2) [알고리즘 문제 풀기 공부하는 법]
# - https://careerly.co.kr/comments/60668
#
# 3) [코딩 면접을 위해 꼭 알아둬야 하는 알고리즘 패턴 8가지와 문제 유형]
# - https://careerly.co.kr/comments/62250
#
# 4) [프로젝트발표영상] 예시
# - https://www.youtube.com/watch?v=ukeIsaagLBI
#
# 5) 데이터 엔지니어가 하는 일은?ㅣ데이터 엔지니어 로드맵, 필요 역량
# - https://www.codestates.com/blog/content/%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4%EB%A1%9C%EB%93%9C%EB%A7%B5
